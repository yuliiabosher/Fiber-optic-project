# %% [markdown]
# <a href="https://colab.research.google.com/github/yuliiabosher/Fiber-optic-project/blob/main/Parliamentary_constituencies_FTTP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install geopandas

# %%
import geopandas as gpd
import pandas as pd

# %%
def read_geojson_file(file):
  df = gpd.read_file(file)
  return df

constituencies = read_geojson_file('https://open-geography-portalx-ons.hub.arcgis.com/api/download/v1/items/a74f3451133140e2a49609f95db2ea64/geojson?layers=0')
display(constituencies.head())
# Out:
#    OBJECTID   PCON21CD                  PCON21NM   BNG_E   BNG_N     LONG  \
# 0         1  E14000530                 Aldershot  484884  155126 -0.78410
# 1         2  E14000531       Aldridge-Brownhills  404723  302568 -1.93166
# 2         3  E14000532  Altrincham and Sale West  374132  389051 -2.39049
# 3         4  E14000533              Amber Valley  440478  349675 -1.39770
# 4         5  E14000534   Arundel and South Downs  510686  115542 -0.42635
#
#         LAT                              GlobalID  \
# 0  51.28895  6fb8422e-dbb5-4615-946d-a50e24755686
# 1  52.62087  ac7ca304-61c9-43ed-8da0-f673850fda51
# 2  53.39766  e9268ad9-79db-4f18-a45a-75b578f4acff
# 3  53.04283  85d80037-63e5-4460-acd6-1da8b91cda9c
# 4  50.92871  27686d42-4500-47bd-8200-79b90f0f4f0a
#
#                                             geometry
# 0  POLYGON ((-0.77547 51.33196, -0.74417 51.30929...
# 1  POLYGON ((-1.90508 52.64321, -1.91599 52.63529...
# 2  POLYGON ((-2.31599 53.43467, -2.34552 53.40789...
# ...
