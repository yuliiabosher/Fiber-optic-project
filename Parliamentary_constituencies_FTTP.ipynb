# %% [markdown]
# <a href="https://colab.research.google.com/github/yuliiabosher/Fiber-optic-project/blob/parliamentary-constituencies/Parliamentary_constituencies_FTTP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Geopandas, Pandas and Matplotlib libraries were imported

# %%
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# The shape file with geometries of the UK parliamentary constituencies was downloaded and uploaded to Github and then read using the Github link. The shape file can be accessed at https://www.data.gov.uk/dataset/76a9c59b-647f-46cc-8511-1cb6d52e5f1d/westminster-parliamentary-constituencies-december-2021-boundaries-uk-buc, Data Links -> Shapefile.  The resulting geodataframe of the UK parliamentary constituencies is as follows

# %%
constituencies = gpd.read_file('https://github.com/yuliiabosher/Fiber-optic-project/raw/refs/heads/parliamentary-constituencies/Westminster_Parliamentary_Constituencies_Dec_2021_UK_BUC_2022_-8882165546947265805.zip')
display(constituencies.head())
# Out:
#     PCON21CD                  PCON21NM   BNG_E   BNG_N     LONG      LAT  \
# 0  E14000530                 Aldershot  484884  155126 -0.78410  51.2890
# 1  E14000531       Aldridge-Brownhills  404723  302568 -1.93166  52.6209
# 2  E14000532  Altrincham and Sale West  374132  389051 -2.39049  53.3977
# 3  E14000533              Amber Valley  440478  349675 -1.39770  53.0428
# 4  E14000534   Arundel and South Downs  510686  115542 -0.42635  50.9287
#
#                                GlobalID  \
# 0  6fb8422e-dbb5-4615-946d-a50e24755686
# 1  ac7ca304-61c9-43ed-8da0-f673850fda51
# 2  e9268ad9-79db-4f18-a45a-75b578f4acff
# 3  85d80037-63e5-4460-acd6-1da8b91cda9c
# 4  27686d42-4500-47bd-8200-79b90f0f4f0a
#
#                                             geometry
# 0  POLYGON ((485406.902 159918.603, 487630.497 15...
# 1  POLYGON ((406519.098 305054.298, 405782.501 30...
# 2  POLYGON ((379104.096 393143.903, 377127.904 39...
# 3  POLYGON ((444868.402 353958.1, 444018.6 351980...
# 4  POLYGON ((506641.497 128757.203, 506993.099 12...

# %% [markdown]
# The columns 'PCON21CD', 'PCON21NM', 'geometry' were separated from the original geodataframe of the UK parliamentary constituencies to create a new cleaned geodataframe

# %%
constituencies_cleaned = constituencies[['PCON21CD', 'PCON21NM', 'geometry']]
display(constituencies_cleaned.head())
# Out:
#     PCON21CD                  PCON21NM  \
# 0  E14000530                 Aldershot
# 1  E14000531       Aldridge-Brownhills
# 2  E14000532  Altrincham and Sale West
# 3  E14000533              Amber Valley
# 4  E14000534   Arundel and South Downs
#
#                                             geometry
# 0  POLYGON ((485406.902 159918.603, 487630.497 15...
# 1  POLYGON ((406519.098 305054.298, 405782.501 30...
# 2  POLYGON ((379104.096 393143.903, 377127.904 39...
# 3  POLYGON ((444868.402 353958.1, 444018.6 351980...
# 4  POLYGON ((506641.497 128757.203, 506993.099 12...

# %% [markdown]
# The file on 2024 Fixed coverage parliamentary constituency data was downloaded from https://www.ofcom.org.uk/phones-and-broadband/coverage-and-speeds/connected-nations-update-spring-2024/, third row "Fixed coverage parliamentary constituency data". Then it was uploaded to Github and read using the Github link. The resulting dataframe is as follows

# %%
ofcom = pd.read_csv("https://raw.githubusercontent.com/yuliiabosher/Fiber-optic-project/refs/heads/parliamentary-constituencies/202401_fixed_pcon_coverage_r01.csv", \
encoding="latin")
display(ofcom.head())
# Out:
#   parl_const parliamentary_constituency_name  All Premises  \
# 0  W07000049                        ABERAVON         33253
# 1  W07000058                       ABERCONWY         30620
# 2  S14000001                  ABERDEEN NORTH         58918
# 3  S14000002                  ABERDEEN SOUTH         54641
# 4  S14000003              AIRDRIE AND SHOTTS         42026
#
#    All Matched Premises  SFBB availability (% premises)  \
# 0                 33216                            98.1
# 1                 30585                            96.3
# 2                 58842                            96.8
# 3                 54580                            97.5
# 4                 42014                            97.8
#
#    UFBB (100Mbit/s) availability (% premises)  UFBB availability (% premises)  \
# 0                                        83.0                            83.0
# 1                                        77.1                            77.1
# 2                                        90.5                            89.9
# 3                                        86.5                            86.1
# 4                                        85.9                            85.9
#
#    Full Fibre availability (% premises)  Gigabit availability (% premises)  \
# 0                                  39.9                               83.0
# 1                                  77.1                               77.1
# 2                                  88.8                               88.8
# 3                                  85.9                               85.9
# 4                                  41.6                               85.9
#
#    % of premises unable to receive 2Mbit/s  ...  \
# 0                                      0.1  ...
# 1                                      0.5  ...
# 2                                      0.0  ...
# 3                                      0.1  ...
# 4                                      0.0  ...
#
#    % of premises with 0<2Mbit/s download speed  \
# 0                                          0.1
# 1                                          0.5
# 2                                          0.0
# 3                                          0.1
# 4                                          0.0
#
#    % of premises with 2<5Mbit/s download speed  \
# 0                                          0.1
# 1                                          0.6
# 2                                          0.0
# 3                                          0.2
# 4                                          0.3
#
#    % of premises with 5<10Mbit/s download speed  \
# 0                                           0.1
# 1                                           0.6
# 2                                           0.1
# 3                                           0.2
# 4                                           0.3
#
#    % of premises with 10<30Mbit/s download speed  \
# 0                                            1.5
# 1                                            1.8
# 2                                            2.9
# 3                                            1.9
# 4                                            1.5
#
#    Number of premises with 30<300Mbit/s download speed  \
# 0                                               5020
# 1                                               5875
# 2                                               4092
# 3                                               6188
# 4                                               5007
#
#    Number of premises with >=300Mbit/s download speed  \
# 0                                              27600
# 1                                              23613
# 2                                              52948
# 3                                              47071
# 4                                              36111
#
#    Number of premises with 0<2Mbit/s download speed  \
# 0                                                40
# 1                                               159
# 2                                                 0
# 3                                                32
# 4                                                13
#
#    Number of premises with 2<5Mbit/s download speed  \
# 0                                                33
# 1                                               195
# 2                                                 1
# 3                                               135
# 4                                               112
#
#    Number of premises with 5<10Mbit/s download speed  \
# 0                                                 35
# 1                                                187
# 2                                                 83
# 3                                                102
# 4                                                125
#
#    Number of premises with 10<30Mbit/s download speed
# 0                                                488
# 1                                                556
# 2                                               1718
# 3                                               1052
# 4                                                646
#
# [5 rows x 40 columns]

# %% [markdown]
# The columns in the original Ofcom dataframe are as follows

# %%
display(ofcom.columns)
# Out:
# Index(['parl_const', 'parliamentary_constituency_name', 'All Premises',
#        'All Matched Premises', 'SFBB availability (% premises)',
#        'UFBB (100Mbit/s) availability (% premises)',
#        'UFBB availability (% premises)',
#        'Full Fibre availability (% premises)',
#        'Gigabit availability (% premises)',
#        '% of premises unable to receive 2Mbit/s',
#        '% of premises unable to receive 5Mbit/s',
#        '% of premises unable to receive 10Mbit/s',
#        '% of premises unable to receive 30Mbit/s',
#        '% of premises below the USO', '% of premises with NGA',
#        '% of premises able to receive decent broadband from FWA',
#        'Number of premises with SFBB availability',
#        'Number of premises with UFBB (100Mbit/s) availability',
#        'Number of premises with UFBB availability',
#        'Number of premises unable to receive 2Mbit/s',
#        'Number of premises unable to receive 5Mbit/s',
#        'Number of premises unable to receive 10Mbit/s',
#        'Number of premises unable to receive 30Mbit/s',
#        'Number of premises with Full Fibre availability',
#        'Number of premises with Gigabit availability',
#        'Number of premises below the USO', 'Number of premises with NGA',
#        'Number of premises able to receive decent broadband from FWA',
#        '% of premises with 30<300Mbit/s download speed',
#        '% of premises with >=300Mbit/s download speed',
#        '% of premises with 0<2Mbit/s download speed',
#        '% of premises with 2<5Mbit/s download speed',
#        '% of premises with 5<10Mbit/s download speed',
#        '% of premises with 10<30Mbit/s download speed',
#        'Number of premises with 30<300Mbit/s download speed',
#        'Number of premises with >=300Mbit/s download speed',
#        'Number of premises with 0<2Mbit/s download speed',
#        'Number of premises with 2<5Mbit/s download speed',
#        'Number of premises with 5<10Mbit/s download speed',
#        'Number of premises with 10<30Mbit/s download speed'],
#       dtype='object')

# %% [markdown]
# The columns 'parl_const',  'parliamentary_constituency_name',  'All Premises',   'Number of premises with Full Fibre availability' were separated from the original Ofcom dataframe to create a new cleaned dataframe

# %%
ofcom_full_fibre = ofcom[['parl_const', 'parliamentary_constituency_name','All Premises', 'Number of premises with Full Fibre availability']]
display(ofcom_full_fibre.head())
# Out:
#   parl_const parliamentary_constituency_name  All Premises  \
# 0  W07000049                        ABERAVON         33253
# 1  W07000058                       ABERCONWY         30620
# 2  S14000001                  ABERDEEN NORTH         58918
# 3  S14000002                  ABERDEEN SOUTH         54641
# 4  S14000003              AIRDRIE AND SHOTTS         42026
#
#    Number of premises with Full Fibre availability
# 0                                            13278
# 1                                            23613
# 2                                            52303
# 3                                            46944
# 4                                            17484

# %% [markdown]
# The number of rows, i.e. the number of parliamentary constituencies in the two cleaned datasets are the same, which means they could be joined without any discrepancies

# %%
display(f'Number of rows in the geodataframe of the UK constituencies - {len(constituencies_cleaned)}')
display(f'Number of rows in the Ofcom dataframe on Fill Fibre availability by constituency - {len(ofcom_full_fibre)}')
# Out:
# 'Number of rows in the geodataframe of the UK constituencies - 650'
# 'Number of rows in the Ofcom dataframe on Fill Fibre availability by constituency - 650'

# %% [markdown]
# The geodatframe of the UK parliamentary constituencies and the dataframe on full fibre by parliamentary constituency were joined on parliamentary constituency code column

# %%
fibre_by_constituency_geo = constituencies_cleaned.merge(ofcom_full_fibre, left_on='PCON21CD', right_on='parl_const')
display(fibre_by_constituency_geo.head())
# Out:
#     PCON21CD                  PCON21NM  \
# 0  E14000530                 Aldershot
# 1  E14000531       Aldridge-Brownhills
# 2  E14000532  Altrincham and Sale West
# 3  E14000533              Amber Valley
# 4  E14000534   Arundel and South Downs
#
#                                             geometry parl_const  \
# 0  POLYGON ((485406.902 159918.603, 487630.497 15...  E14000530
# 1  POLYGON ((406519.098 305054.298, 405782.501 30...  E14000531
# 2  POLYGON ((379104.096 393143.903, 377127.904 39...  E14000532
# 3  POLYGON ((444868.402 353958.1, 444018.6 351980...  E14000533
# 4  POLYGON ((506641.497 128757.203, 506993.099 12...  E14000534
#
#   parliamentary_constituency_name  All Premises  \
# 0                       ALDERSHOT         48683
# 1             ALDRIDGE-BROWNHILLS         34293
# 2        ALTRINCHAM AND SALE WEST         45481
# 3                    AMBER VALLEY         45332
# 4         ARUNDEL AND SOUTH DOWNS         50925
#
#    Number of premises with Full Fibre availability
# 0                                            35403
# 1                                            21361
# 2                                            35846
# 3                                            34471
# 4                                            23675

# %% [markdown]
# The joined dataframe had the same number of rows as the original two, which means no constituency was left out

# %%
display(f'The legth of the merged dataframe is {len(fibre_by_constituency_geo)}')
# Out:
# 'The legth of the merged dataframe is 650'

# %% [markdown]
# The columns with duplicated data in the joined geodataframe were dropped

# %%
fibre_by_constituency_geo.drop('parl_const', axis=1, inplace=True)
fibre_by_constituency_geo.drop('parliamentary_constituency_name', axis=1, inplace=True)
display(fibre_by_constituency_geo.head())
# Out:
#     PCON21CD                  PCON21NM  \
# 0  E14000530                 Aldershot
# 1  E14000531       Aldridge-Brownhills
# 2  E14000532  Altrincham and Sale West
# 3  E14000533              Amber Valley
# 4  E14000534   Arundel and South Downs
#
#                                             geometry  All Premises  \
# 0  POLYGON ((485406.902 159918.603, 487630.497 15...         48683
# 1  POLYGON ((406519.098 305054.298, 405782.501 30...         34293
# 2  POLYGON ((379104.096 393143.903, 377127.904 39...         45481
# 3  POLYGON ((444868.402 353958.1, 444018.6 351980...         45332
# 4  POLYGON ((506641.497 128757.203, 506993.099 12...         50925
#
#    Number of premises with Full Fibre availability
# 0                                            35403
# 1                                            21361
# 2                                            35846
# 3                                            34471
# 4                                            23675

# %% [markdown]
# The columns in the joined geodataframe were renamed

# %%
fibre_by_constituency_geo.columns = ['Constituency Code', 'Constituency Name', 'geometry', 'Total Premises', 'Premises with Full Fibre Availability']
display(fibre_by_constituency_geo.head())
# Out:
#   Constituency Code         Constituency Name  \
# 0         E14000530                 Aldershot
# 1         E14000531       Aldridge-Brownhills
# 2         E14000532  Altrincham and Sale West
# 3         E14000533              Amber Valley
# 4         E14000534   Arundel and South Downs
#
#                                             geometry  Total Premises  \
# 0  POLYGON ((485406.902 159918.603, 487630.497 15...           48683
# 1  POLYGON ((406519.098 305054.298, 405782.501 30...           34293
# 2  POLYGON ((379104.096 393143.903, 377127.904 39...           45481
# 3  POLYGON ((444868.402 353958.1, 444018.6 351980...           45332
# 4  POLYGON ((506641.497 128757.203, 506993.099 12...           50925
#
#    Premises with Full Fibre Availability
# 0                                  35403
# 1                                  21361
# 2                                  35846
# 3                                  34471
# 4                                  23675

# %% [markdown]
# It was verified that 'Total Premises' and 'Premises with Full Fibre Availability' columns were integer data type

# %%
display(fibre_by_constituency_geo.info())
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 650 entries, 0 to 649
# Data columns (total 5 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Constituency Code                      650 non-null    object
#  1   Constituency Name                      650 non-null    object
#  2   geometry                               650 non-null    geometry
#  3   Total Premises                         650 non-null    int64
#  4   Premises with Full Fibre Availability  650 non-null    int64
# dtypes: geometry(1), int64(2), object(2)
# memory usage: 25.5+ KB
# None

# %% [markdown]
# A new column titled 'Percentage of Premises with Full Fibre Availability' was added. The column was the result of 'Premises with Full Fibre Availability' column divided by 'Total Premises' column

# %%
fibre_by_constituency_geo['Percentage of Premises with Full Fibre Availability'] = \
fibre_by_constituency_geo['Premises with Full Fibre Availability'] / fibre_by_constituency_geo['Total Premises']
display(fibre_by_constituency_geo.head())
# Out:
#   Constituency Code         Constituency Name  \
# 0         E14000530                 Aldershot
# 1         E14000531       Aldridge-Brownhills
# 2         E14000532  Altrincham and Sale West
# 3         E14000533              Amber Valley
# 4         E14000534   Arundel and South Downs
#
#                                             geometry  Total Premises  \
# 0  POLYGON ((485406.902 159918.603, 487630.497 15...           48683
# 1  POLYGON ((406519.098 305054.298, 405782.501 30...           34293
# 2  POLYGON ((379104.096 393143.903, 377127.904 39...           45481
# 3  POLYGON ((444868.402 353958.1, 444018.6 351980...           45332
# 4  POLYGON ((506641.497 128757.203, 506993.099 12...           50925
#
#    Premises with Full Fibre Availability  \
# 0                                  35403
# 1                                  21361
# 2                                  35846
# 3                                  34471
# 4                                  23675
#
#    Percentage of Premises with Full Fibre Availability
# 0                                           0.727215
# 1                                           0.622897
# 2                                           0.788153
# 3                                           0.760412
# 4                                           0.464899

# %% [markdown]
# The 'Percentage of Premises with Full Fibre Availability' column was plotted as a cholopleth

# %%
fig, ax = plt.subplots(1, 1)
fibre_by_constituency_geo.plot(column='Percentage of Premises with Full Fibre Availability', cmap='Blues', legend=True, ax=ax, legend_kwds={'shrink': 0.7})
fig.set_size_inches(8,6)
plt.style.use('seaborn-v0_8-whitegrid')
font = {'family':'monospace','color':'black','size':12}
ax.set_title('Percentage of Premises with \nFull Fibre Availability by Constituency', fontdict = font)
plt.axis('off')
plt.show()

# %% [markdown]
# The file with percentages of highly rural, rural and urban areas in each parliamentary constituency can be accessed at https://pages.mysociety.org/uk_ruc/downloads/uk_ruc_xlsx/latest#survey

# %%
uk_ruc = pd.read_excel('https://pages.mysociety.org/uk_ruc/data/uk_ruc/latest/uk_ruc.xlsx', sheet_name='pcon_ruc')
display(uk_ruc)
# Out:
#       gss-code          constituency-name  highly-rural     rural     urban  \
# 0    E14000530                  Aldershot      0.000000  0.000000  1.000000
# 1    E14000531        Aldridge-Brownhills      0.000000  0.019661  0.980339
# 2    E14000532   Altrincham and Sale West      0.014491  0.000000  0.985509
# 3    E14000533               Amber Valley      0.063376  0.104215  0.832410
# 4    E14000534    Arundel and South Downs      0.217022  0.549331  0.233648
# ..         ...                        ...           ...       ...       ...
# 645  W07000076                 Caerphilly      0.017662  0.157868  0.824470
# 646  W07000077                     Islwyn      0.037792  0.072151  0.890057
# 647  W07000078          Vale of Glamorgan      0.147526  0.098641  0.753833
# 648  W07000079               Cardiff West      0.000000  0.051872  0.948128
# 649  W07000080  Cardiff South and Penarth      0.000000  0.000000  1.000000
#
#           ruc-cluster-label
# 0                     Urban
# 1                     Urban
# 2                     Urban
# 3    Urban with rural areas
# 4                     Rural
# ..                      ...
# 645  Urban with rural areas
# 646                   Urban
# 647  Urban with rural areas
# 648                   Urban
# 649                   Urban
#
# [650 rows x 6 columns]

# %% [markdown]
# The dataframe with rural/urban data was merged with the dataframe on full fibre availability by parliamentary constituency.

# %%
fibre_by_constituency_geo = fibre_by_constituency_geo.merge(uk_ruc, left_on='Constituency Code', right_on='gss-code')
display(fibre_by_constituency_geo.info())
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 650 entries, 0 to 649
# Data columns (total 12 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   Constituency Code                                    650 non-null    object
#  1   Constituency Name                                    650 non-null    object
#  2   geometry                                             650 non-null    geometry
#  3   Total Premises                                       650 non-null    int64
#  4   Premises with Full Fibre Availability                650 non-null    int64
#  5   Percentage of Premises with Full Fibre Availability  650 non-null    float64
#  6   gss-code                                             650 non-null    object
#  7   constituency-name                                    650 non-null    object
#  8   highly-rural                                         650 non-null    float64
#  9   rural                                                650 non-null    float64
#  10  urban                                                650 non-null    float64
#  11  ruc-cluster-label                                    650 non-null    object
# dtypes: float64(4), geometry(1), int64(2), object(5)
# memory usage: 61.1+ KB
# None

# %% [markdown]
# Duplicate columns 'gss-code' and 'constituency-name' were dropped from the merged dataframe.

# %%
fibre_by_constituency_geo.drop('gss-code', axis=1, inplace=True)
fibre_by_constituency_geo.drop('constituency-name', axis=1, inplace=True)
display(fibre_by_constituency_geo.head())
# Out:
#   Constituency Code         Constituency Name  \
# 0         E14000530                 Aldershot
# 1         E14000531       Aldridge-Brownhills
# 2         E14000532  Altrincham and Sale West
# 3         E14000533              Amber Valley
# 4         E14000534   Arundel and South Downs
#
#                                             geometry  Total Premises  \
# 0  POLYGON ((485406.902 159918.603, 487630.497 15...           48683
# 1  POLYGON ((406519.098 305054.298, 405782.501 30...           34293
# 2  POLYGON ((379104.096 393143.903, 377127.904 39...           45481
# 3  POLYGON ((444868.402 353958.1, 444018.6 351980...           45332
# 4  POLYGON ((506641.497 128757.203, 506993.099 12...           50925
#
#    Premises with Full Fibre Availability  \
# 0                                  35403
# 1                                  21361
# 2                                  35846
# 3                                  34471
# 4                                  23675
#
#    Percentage of Premises with Full Fibre Availability  highly-rural  \
# 0                                           0.727215        0.000000
# 1                                           0.622897        0.000000
# 2                                           0.788153        0.014491
# 3                                           0.760412        0.063376
# 4                                           0.464899        0.217022
#
#       rural     urban       ruc-cluster-label
# 0  0.000000  1.000000                   Urban
# 1  0.019661  0.980339                   Urban
# 2  0.000000  0.985509                   Urban
# 3  0.104215  0.832410  Urban with rural areas
# 4  0.549331  0.233648                   Rural

# %% [markdown]
# The newly merged columns were renamed.

# %%
fibre_by_constituency_geo.columns = ['Constituency Code', 'Constituency Name', 'geometry', 'Total Premises', 'Premises with Full Fibre Availability', \
                                     'Percentage of Premises with Full Fibre Availability', 'Highly Rural', 'Rural', 'Urban', 'Label']
display(fibre_by_constituency_geo.head())
# Out:
#   Constituency Code         Constituency Name  \
# 0         E14000530                 Aldershot
# 1         E14000531       Aldridge-Brownhills
# 2         E14000532  Altrincham and Sale West
# 3         E14000533              Amber Valley
# 4         E14000534   Arundel and South Downs
#
#                                             geometry  Total Premises  \
# 0  POLYGON ((485406.902 159918.603, 487630.497 15...           48683
# 1  POLYGON ((406519.098 305054.298, 405782.501 30...           34293
# 2  POLYGON ((379104.096 393143.903, 377127.904 39...           45481
# 3  POLYGON ((444868.402 353958.1, 444018.6 351980...           45332
# 4  POLYGON ((506641.497 128757.203, 506993.099 12...           50925
#
#    Premises with Full Fibre Availability  \
# 0                                  35403
# 1                                  21361
# 2                                  35846
# 3                                  34471
# 4                                  23675
#
#    Percentage of Premises with Full Fibre Availability  Highly Rural  \
# 0                                           0.727215        0.000000
# 1                                           0.622897        0.000000
# 2                                           0.788153        0.014491
# 3                                           0.760412        0.063376
# 4                                           0.464899        0.217022
#
#       Rural     Urban                   Label
# 0  0.000000  1.000000                   Urban
# 1  0.019661  0.980339                   Urban
# 2  0.000000  0.985509                   Urban
# 3  0.104215  0.832410  Urban with rural areas
# 4  0.549331  0.233648                   Rural
